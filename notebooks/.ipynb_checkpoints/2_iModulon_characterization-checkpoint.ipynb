# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Check-your-sample-table-(i.e.-metadata-file)" data-toc-modified-id="Check-your-sample-table-(i.e.-metadata-file)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Check your sample table (i.e. metadata file)</a></span></li><li><span><a href="#Check-your-TRN" data-toc-modified-id="Check-your-TRN-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Check your TRN</a></span></li><li><span><a href="#Load-the-data" data-toc-modified-id="Load-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Load the data</a></span></li></ul></li><li><span><a href="#Regulatory-iModulons" data-toc-modified-id="Regulatory-iModulons-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Regulatory iModulons</a></span></li><li><span><a href="#Functional-iModulons" data-toc-modified-id="Functional-iModulons-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Functional iModulons</a></span><ul class="toc-item"><li><span><a href="#GO-Enrichments" data-toc-modified-id="GO-Enrichments-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>GO Enrichments</a></span></li><li><span><a href="#KEGG-Enrichments" data-toc-modified-id="KEGG-Enrichments-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>KEGG Enrichments</a></span><ul class="toc-item"><li><span><a href="#Load-KEGG-mapping" data-toc-modified-id="Load-KEGG-mapping-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Load KEGG mapping</a></span></li><li><span><a href="#Perform-enrichment" data-toc-modified-id="Perform-enrichment-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Perform enrichment</a></span></li><li><span><a href="#Convert-KEGG-IDs-to-human-readable-names" data-toc-modified-id="Convert-KEGG-IDs-to-human-readable-names-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Convert KEGG IDs to human-readable names</a></span></li></ul></li><li><span><a href="#SubtiWiki-categories" data-toc-modified-id="SubtiWiki-categories-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SubtiWiki categories</a></span></li><li><span><a href="#Save-files" data-toc-modified-id="Save-files-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Save files</a></span></li></ul></li><li><span><a href="#Check-for-single-gene-iModulons" data-toc-modified-id="Check-for-single-gene-iModulons-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Check for single gene iModulons</a></span></li><li><span><a href="#Save-iModulon-object" data-toc-modified-id="Save-iModulon-object-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Save iModulon object</a></span></li></ul></div>

# %% [markdown]
# # Setup
# This IPython notebook will walk through the steps of characterizing iModulons through the semi-automated tools in PyModulon. You will need:
#
# * M and A matrices
# * Expression data (e.g. `log_tpm_norm.csv`)
# * Gene table and KEGG/GO annotations (Generated in `gene_annotation.ipynb`)
# * Sample table, with a column for `project` and `condition`
# * TRN file
#
# Optional:
# * iModulon table (if you already have some characterized iModulons)

# %%
from pymodulon.core import IcaData
from pymodulon.plotting import *
from os import path
import pandas as pd
import re
from Bio.KEGG import REST
from tqdm.notebook import tqdm

# %%
# Enter the location of your data here
data_dir = path.join('..','data','processed_data')

# GO and KEGG annotations are in the 'external' folder
external_data = path.join('..','data','external')

# %% [markdown]
# ## Check your sample table (i.e. metadata file)
# Your metadata file will probably have a lot of columns, most of which you may not care about. Feel free to save a secondary copy of your metadata file with only columns that seem relevant to you. The two most important columns are:
# 1. `project`
# 2. `condition`
#
# Make sure that these columns exist in your metadata file

# %%
df_metadata = pd.read_csv(path.join(data_dir,'metadata.tsv'),index_col=0,sep='\t')
df_metadata[['project','condition']].head()
# Out:
#                       project       condition
# Experiment
# SRX10864008  photomixotrophic  photoautotroph
# SRX10864009  photomixotrophic  photoautotroph
# SRX10864010  photomixotrophic  photoautotroph
# SRX10864011  photomixotrophic         glucose
# SRX10864012  photomixotrophic         glucose

# %%
print(df_metadata.project.notnull().all())
print(df_metadata.condition.notnull().all())
# Out:
# True
# True

# %% [markdown]
# ## Check your TRN

# %% [markdown]
# Each row of the TRN file represents a regulatory interaction.
# **Your TRN file must have the following columns:**
# 1. `regulator` - Name of regulator (`/` or `+` characters will be converted to `;`)
# 1. `gene_id` - Locus tag of gene being regulated
#
# The following columns are optional, but are helpful to have:
# 1. `regulator_id` - Locus tag of regulator
# 1. `gene_name` - Name of gene (can automatically update this using `name2num`)
# 1. `direction` - Direction of regulation ('+' for activation, '-' for repression, '?' or NaN for unknown)
# 1. `evidence` - Evidence of regulation (e.g. ChIP-exo, qRT-PCR, SELEX, Motif search)
# 1. `PMID` - Reference for regulation
#
# You may add any other columns that could help you. TRNs may be saved as either CSV or TSV files. See below for an example:

# %%
df_trn = pd.read_csv(path.join(external_data,'TRN.csv'))
df_trn.head()
# Out:
#          regulator_id regulator repressor           gene_name  \
# 0                 NaN      dnaN       NaN  SYNPCC7942_RS00005
# 1  SYNPCC7942_RS00645      NtcA       NaN                ntcA
# 2                 NaN      pdhB       NaN  SYNPCC7942_RS00725
# 3  SYNPCC7942_RS00645      NtcA       NaN                glnN
# 4                 NaN       ggt       NaN  SYNPCC7942_RS00940
#
#               gene_id    old_locus_tag  \
# 0  SYNPCC7942_RS00005  Synpcc7942_0001
# 1  SYNPCC7942_RS00645  Synpcc7942_0127
# 2  SYNPCC7942_RS00725  Synpcc7942_0143
# 3  SYNPCC7942_RS00860  Synpcc7942_0169
# 4  SYNPCC7942_RS00940  Synpcc7942_0185
#
#                                 gene_product  \
# 0            DNA polymerase III subunit beta
# 1             global nitrogen regulator NtcA
# 2  alpha-ketoacid dehydrogenase subunit beta
# 3                       glutamine synthetase
# 4               gamma-glutamyltranspeptidase
#
#                                   COG Direction Operon_based_assumption  \
# 0              Replication and repair       NaN                     NaN
# 1                       Transcription       NaN                     NaN
# 2    Energy production and conversion       NaN                     NaN
# 3                    Function Unknown       NaN                     NaN
# 4  Amino Acid metabolis and transport       NaN                     NaN
#
#   Evidence PMID Additional Notes
# 0      NaN  NaN              NaN
# 1      NaN  NaN              NaN
# 2      NaN  NaN              NaN
# 3      NaN  NaN              NaN
# 4      NaN  NaN              NaN

# %% [markdown]
# The `regulator` and `gene_id` must be filled in for each row

# %%
print(df_trn.regulator.notnull().all())
print(df_trn.gene_id.notnull().all())
# Out:
# True
# True

# %% [markdown]
# ## Load the data
# You're now ready to load your IcaData object!

# %%
data_dir
# Out:
# '../data/processed_data'

# %%
ica_data = IcaData(M = path.join('../data/processed_data/dimensions/120_optimal/','S.csv'),
                   A = path.join('../data/processed_data//dimensions/120_optimal/','A.csv'),
                   X = path.join(data_dir,'log_tpm_norm.csv'),
                   gene_table = path.join(data_dir,'gene_info.csv'),
                   sample_table = path.join(data_dir,'metadata.tsv'),
#                    trn = path.join(external_data,'TRN.csv'),
                   optimize_cutoff=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pymodulon/util.py in _check_table(table, name, index, index_col)
#      30         try:
# ---> 31             table = pd.read_json(table)
#      32         except ValueError:
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#
# ValueError: Expected object or value
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1643543/654661567.py in <module>
#       5                    sample_table = path.join(data_dir,'metadata.tsv'),
#       6 #                    trn = path.join(external_data,'TRN.csv'),
# ----> 7                    optimize_cutoff=True)
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pymodulon/core.py in __init__(self, M, A, X, log_tpm, gene_table, sample_table, imodulon_table, trn, dagostino_cutoff, optimize_cutoff, thresholds, threshold_method, motif_info, imodulondb_table, gene_links, tf_links)
#     101         #########################
#     102
# --> 103         M = _check_table(M, "M")
#     104         A = _check_table(A, "A")
#     105
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pymodulon/util.py in _check_table(table, name, index, index_col)
#      32         except ValueError:
#      33             sep = "\t" if table.endswith(".tsv") else ","
# ---> 34             table = pd.read_csv(table, index_col=index_col, sep=sep)
#      35
#      36     # Coerce indices and columns to ints if necessary
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annie/Downloads/dimensions/55/S.csv'

# %%
from pymodulon.io import *
old = load_json_model(path.join('/home/annie/Documents/small-genome-pangenome/H_influenzae/iModulons/KW20/interim/','hi_raw.json.gz'))

# %%
from pymodulon.compare import *

# %%
plot_activities(ica_data,5,projects=['competence'])
# Out:
# <AxesSubplot:ylabel='5 iModulon\nActivity'>

# %%
ica_data = load_json_model('/home/annie/Documents/small-genome-pangenome/H_influenzae/iModulons/KW20/interim/kw20.json.gz')

# %%
dots,links = compare_ica(ica_data.M,old.M,cutoff=0.3,
                         ortho_file = '/home/annie/Documents/small-genome-pangenome/H_influenzae/iModulons/bbh/KW20_vs_KW20_parsed.csv')
links

# %%
set(old.imodulon_names) - set([x[1] for x in dots])
# Out:
# {41, 44, 'SG_1', 'SG_6', 'SG_9', 'unchar-1'}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cluster_activities(ica_data,
                  correlation_method = 'mutual_info',
                  dimca_sample1='competence:kw20_t0',
                  dimca_sample2='competence:kw20_t10',
                  show_clustermap = True,
                  show_best_clusters = True)
# Out:
# [AgglomerativeClustering(affinity='precomputed', compute_full_tree=True,
#                          distance_threshold=0.9500000000000001,
#                          linkage='complete', n_clusters=None),
#  <AxesSubplot:xlabel='competence:kw20_t0', ylabel='competence:kw20_t10'>]

# %%
set(old.imodulon_names) - set([x[1] for x in dots])
# Out:
# {41, 44, 'SG_1', 'SG_6', 'SG_9', 'unchar-1'}

# %%
ica_data = IcaData(M = path.join(data_dir,'M.csv'),
                   A = path.join(data_dir,'A.csv'),
                   X = path.join(data_dir,'log_tpm_norm.csv'),
                   gene_table = path.join(data_dir,'gene_info.csv'),
                   sample_table = path.join(data_dir,'metadata.tsv'),
                   trn = path.join(external_data,'TRN.csv'),
                   optimize_cutoff=True)
# Out:
# WARNING:root:The following genes are in the TRN but not in your M matrix: {'HI_10643', 'HI_1097.m', 'HI_1096.m', 'HI_0050.m'}
# WARNING:root:Optimizing iModulon thresholds, may take 2-3 minutes...

# %% [markdown]
# If you don't have a TRN (or have a very minimal TRN), use `threshold_method = 'kmeans'`

# %%
# ica_data = IcaData(M = path.join(data_dir,'M.csv'),
#                    A = path.join(data_dir,'A.csv'),
#                    X = path.join(data_dir,'log_tpm_norm.csv'),
#                    gene_table = path.join(data_dir,'gene_info.csv'),
#                    sample_table = path.join(data_dir,'metadata.tsv'),
#                    trn = path.join(data_dir,'TRN.csv'),
#                    threshold_method = 'kmeans')

# %% [markdown]
# # Regulatory iModulons
# Use `compute_trn_enrichment` to automatically check for Regulatory iModulons. The more complete your TRN, the more regulatory iModulons you'll find.

# %%
ica_data.compute_trn_enrichment()
# Out:
#     imodulon regulator        pvalue        qvalue  precision    recall  \
# 0          0      TrpR  1.167011e-19  1.167011e-19   0.692308  0.818182
# 1          7      FeHm  1.385089e-10  1.385089e-09   0.375000  0.159574
# 2          9      NimR  2.691412e-07  2.691412e-07   0.375000  0.750000
# 3         11       CRP  1.599720e-17  1.599720e-17   0.769231  0.400000
# 4         11       Sxy  1.599720e-17  1.599720e-17   0.769231  0.400000
# 5         14      FeHm  3.036741e-21  1.214696e-20   0.777778  0.148936
# 6         14       Fur  7.154703e-13  1.430941e-12   0.277778  0.500000
# 7         16      NarP  2.127768e-24  6.383303e-24   0.435897  0.680000
# 8         16      FeHm  2.459017e-09  3.688525e-09   0.487179  0.101064
# 9         18      PurR  6.466229e-18  5.819606e-17   0.244898  0.857143
# 10        19      MetR  3.339324e-08  2.337527e-07   0.235294  0.800000
# 11        23       CRP  4.472261e-31  2.012517e-30   0.306667  0.920000
# 12        23       Sxy  4.472261e-31  2.012517e-30   0.306667  0.920000
# 13        29      ArgR  2.056349e-16  4.112697e-16   0.538462  1.000000
# 14        36       CRP  1.210653e-07  3.026632e-07   0.225806  0.280000
# 15        36       Sxy  1.210653e-07  3.026632e-07   0.225806  0.280000
#
#      f1score    TP  regulon_size  imodulon_size  n_regs
# 0   0.750000   9.0          11.0           13.0     1.0
# 1   0.223881  30.0         188.0           80.0     1.0
# 2   0.500000   3.0           4.0            8.0     1.0
# 3   0.526316  10.0          25.0           13.0     1.0
# 4   0.526316  10.0          25.0           13.0     1.0
# 5   0.250000  28.0         188.0           36.0     1.0
# 6   0.357143  10.0          20.0           36.0     1.0
# 7   0.531250  17.0          25.0           39.0     1.0
# 8   0.167401  19.0         188.0           39.0     1.0
# 9   0.380952  12.0          14.0           49.0     1.0
# 10  0.363636   4.0           5.0           17.0     1.0
# 11  0.460000  23.0          25.0           75.0     1.0
# 12  0.460000  23.0          25.0           75.0     1.0
# 13  0.700000   7.0           7.0           13.0     1.0
# 14  0.250000   7.0          25.0           31.0     1.0
# 15  0.250000   7.0          25.0           31.0     1.0

# %% [markdown]
# You can also search for AND/OR combinations of regulators using the `max_regs` argument.
#
# Regulator enrichments can be directly saved to the `imodulon_table` using the `save` argument. This saves the enrichment with the lowest q-value to the table.

# %%
# First search for regulator enrichments with 2 regulators
ica_data.compute_trn_enrichment(max_regs=2,save=True)

# Next, search for regulator enrichments with just one regulator. This will supercede the 2 regulator enrichments.
ica_data.compute_trn_enrichment(max_regs=1,save=True)
# Out:
#     imodulon regulator        pvalue        qvalue  precision    recall  \
# 0          0      TrpR  1.167011e-19  1.167011e-19   0.692308  0.818182
# 1          7      FeHm  1.385089e-10  1.385089e-09   0.375000  0.159574
# 2          9      NimR  2.691412e-07  2.691412e-07   0.375000  0.750000
# 3         11       CRP  1.599720e-17  1.599720e-17   0.769231  0.400000
# 4         11       Sxy  1.599720e-17  1.599720e-17   0.769231  0.400000
# 5         14      FeHm  3.036741e-21  1.214696e-20   0.777778  0.148936
# 6         14       Fur  7.154703e-13  1.430941e-12   0.277778  0.500000
# 7         16      NarP  2.127768e-24  6.383303e-24   0.435897  0.680000
# 8         16      FeHm  2.459017e-09  3.688525e-09   0.487179  0.101064
# 9         18      PurR  6.466229e-18  5.819606e-17   0.244898  0.857143
# 10        19      MetR  3.339324e-08  2.337527e-07   0.235294  0.800000
# 11        23       CRP  4.472261e-31  2.012517e-30   0.306667  0.920000
# 12        23       Sxy  4.472261e-31  2.012517e-30   0.306667  0.920000
# 13        29      ArgR  2.056349e-16  4.112697e-16   0.538462  1.000000
# 14        36       CRP  1.210653e-07  3.026632e-07   0.225806  0.280000
# 15        36       Sxy  1.210653e-07  3.026632e-07   0.225806  0.280000
#
#      f1score    TP  regulon_size  imodulon_size  n_regs
# 0   0.750000   9.0          11.0           13.0     1.0
# 1   0.223881  30.0         188.0           80.0     1.0
# 2   0.500000   3.0           4.0            8.0     1.0
# 3   0.526316  10.0          25.0           13.0     1.0
# 4   0.526316  10.0          25.0           13.0     1.0
# 5   0.250000  28.0         188.0           36.0     1.0
# 6   0.357143  10.0          20.0           36.0     1.0
# 7   0.531250  17.0          25.0           39.0     1.0
# 8   0.167401  19.0         188.0           39.0     1.0
# 9   0.380952  12.0          14.0           49.0     1.0
# 10  0.363636   4.0           5.0           17.0     1.0
# 11  0.460000  23.0          25.0           75.0     1.0
# 12  0.460000  23.0          25.0           75.0     1.0
# 13  0.700000   7.0           7.0           13.0     1.0
# 14  0.250000   7.0          25.0           31.0     1.0
# 15  0.250000   7.0          25.0           31.0     1.0

# %% [markdown]
# The list of regulatory iModulons are shown below

# %%
regulatory_imodulons = ica_data.imodulon_table[ica_data.imodulon_table.regulator.notnull()]
print(len(ica_data.imodulon_table),'Total iModulons')
print(len(regulatory_imodulons),'Regulatory iModulons')
regulatory_imodulons
# Out:
# 45 Total iModulons
# 11 Regulatory iModulons
#    regulator        pvalue        qvalue  precision    recall   f1score    TP  \
# 0       TrpR  1.167011e-19  1.167011e-19   0.692308  0.818182  0.750000   9.0
# 7       FeHm  1.385089e-10  1.385089e-09   0.375000  0.159574  0.223881  30.0
# 9       NimR  2.691412e-07  2.691412e-07   0.375000  0.750000  0.500000   3.0
# 11       CRP  1.599720e-17  1.599720e-17   0.769231  0.400000  0.526316  10.0
# 14      FeHm  3.036741e-21  1.214696e-20   0.777778  0.148936  0.250000  28.0
# 16      NarP  2.127768e-24  6.383303e-24   0.435897  0.680000  0.531250  17.0
# 18      PurR  6.466229e-18  5.819606e-17   0.244898  0.857143  0.380952  12.0
# 19      MetR  3.339324e-08  2.337527e-07   0.235294  0.800000  0.363636   4.0
# 23       CRP  4.472261e-31  2.012517e-30   0.306667  0.920000  0.460000  23.0
# 29      ArgR  2.056349e-16  4.112697e-16   0.538462  1.000000  0.700000   7.0
# 36       CRP  1.210653e-07  3.026632e-07   0.225806  0.280000  0.250000   7.0
#
#     regulon_size  imodulon_size  n_regs
# 0           11.0           13.0     1.0
# 7          188.0           80.0     1.0
# 9            4.0            8.0     1.0
# 11          25.0           13.0     1.0
# 14         188.0           36.0     1.0
# 16          25.0           39.0     1.0
# 18          14.0           49.0     1.0
# 19           5.0           17.0     1.0
# 23          25.0           75.0     1.0
# 29           7.0           13.0     1.0
# 36          25.0           31.0     1.0

# %% [markdown]
# You can rename iModulons in this jupyter notebook, or you can save the iModulon table as a CSV and edit it in Excel.
#
# If two iModulons have the same regulator (e.g. 'Reg'), they will be named 'Reg-1' and 'Reg-2'

# %%
ica_data.rename_imodulons(regulatory_imodulons.regulator.to_dict())
ica_data.imodulon_table.head()
# Out:
# WARNING:root:Duplicate iModulon names detected. iModulon 7 will be renamed to FeHm-1
# WARNING:root:Duplicate iModulon names detected. iModulon 11 will be renamed to CRP-1
# WARNING:root:Duplicate iModulon names detected. iModulon 14 will be renamed to FeHm-2
# WARNING:root:Duplicate iModulon names detected. iModulon 23 will be renamed to CRP-2
# WARNING:root:Duplicate iModulon names detected. iModulon 36 will be renamed to CRP-3
#      regulator        pvalue        qvalue  precision    recall  f1score   TP  \
# TrpR      TrpR  1.167011e-19  1.167011e-19   0.692308  0.818182     0.75  9.0
# 1          NaN           NaN           NaN        NaN       NaN      NaN  NaN
# 2          NaN           NaN           NaN        NaN       NaN      NaN  NaN
# 3          NaN           NaN           NaN        NaN       NaN      NaN  NaN
# 4          NaN           NaN           NaN        NaN       NaN      NaN  NaN
#
#       regulon_size  imodulon_size  n_regs
# TrpR          11.0           13.0     1.0
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN
# 3              NaN            NaN     NaN
# 4              NaN            NaN     NaN

# %%
regulatory_imodulons = ica_data.imodulon_table[ica_data.imodulon_table.regulator.notnull()]

# %% [markdown]
# # Functional iModulons

# %% [markdown]
# GO annotations and KEGG pathways/modules were generated in the 1_create_the_gene_table.ipynb notebook. Enrichments will be calculated in this notebook, and further curated in the 3_manual_iModulon_curation notebook.

# %% [markdown]
# ## GO Enrichments

# %% [markdown]
# First load the Gene Ontology annotations

# %%
DF_GO = pd.read_csv(path.join(external_data,'GO_annotations_curated.csv'),index_col=0)
DF_GO.head()
# Out:
#    gene_id gene_name                                      gene_ontology
# 0  HI_0509      menA                     vitamin K biosynthetic process
# 1  HI_0509      menA  ubiquinone biosynthetic process via 3,4-dihydr...
# 2  HI_0509      menA                   menaquinone biosynthetic process
# 3  HI_0509      menA                                    plasma membrane
# 4  HI_0509      menA                         prenyltransferase activity

# %%
DF_GO_enrich = ica_data.compute_annotation_enrichment(DF_GO,'gene_ontology')

# %%
DF_GO_enrich.head()
# Out:
#   imodulon                                 gene_ontology        pvalue  \
# 0     TrpR               tryptophan biosynthetic process  4.158074e-12
# 1        4  L-cystine transmembrane transporter activity  5.344347e-05
# 2       15            structural constituent of ribosome  4.651540e-28
# 3       15             cytosolic large ribosomal subunit  3.774595e-20
# 4       15             cytosolic small ribosomal subunit  4.789011e-08
#
#          qvalue  precision    recall   f1score    TP  target_set_size  \
# 0  4.636252e-09   0.461538  0.666667  0.545455   6.0              9.0
# 1  5.958947e-02   0.153846  1.000000  0.266667   2.0              2.0
# 2  5.186467e-25   0.583333  0.525000  0.552632  21.0             40.0
# 3  2.104337e-17   0.416667  0.555556  0.476190  15.0             27.0
# 4  1.779916e-05   0.166667  0.500000  0.250000   6.0             12.0
#
#    imodulon_size
# 0           13.0
# 1           13.0
# 2           36.0
# 3           36.0
# 4           36.0

# %% [markdown]
# ## KEGG Enrichments

# %% [markdown]
# ### Load KEGG mapping
# The `kegg_mapping.csv` file contains KEGG orthologies, pathways, modules, and reactions. Only pathways and modules are relevant to iModulon characterization.

# %%
DF_KEGG = pd.read_csv(path.join(external_data,'kegg_mapping.csv'),index_col=0)
print(DF_KEGG.database.unique())
DF_KEGG.head()
# Out:
# ['KEGG_orth' 'KEGG_pathway' 'KEGG_module' 'KEGG_reaction']
#     gene_id   database kegg_id
# 2   HI_0003  KEGG_orth       -
# 38  HI_0040  KEGG_orth       -
# 46  HI_0048  KEGG_orth       -
# 51  HI_0053  KEGG_orth       -
# 54  HI_0056  KEGG_orth       -

# %%
kegg_pathways = DF_KEGG[DF_KEGG.database == 'KEGG_pathway']
kegg_modules = DF_KEGG[DF_KEGG.database == 'KEGG_module']

# %% [markdown]
# ### Perform enrichment
# Uses the `compute_annotation_enrichment` function

# %%
DF_pathway_enrich = ica_data.compute_annotation_enrichment(kegg_pathways,'kegg_id')
DF_module_enrich = ica_data.compute_annotation_enrichment(kegg_modules,'kegg_id')

# %%
DF_pathway_enrich.head()
# Out:
#   imodulon   kegg_id        pvalue        qvalue  precision    recall  \
# 0     TrpR  map00400  1.296331e-09  2.385249e-07   0.461538  0.315789
# 1     TrpR  map01230  1.647545e-05  1.515741e-03   0.461538  0.070588
# 2     TrpR  map00405  5.344347e-05  3.277866e-03   0.153846  1.000000
# 3     TrpR  map01130  1.743338e-04  8.019353e-03   0.461538  0.046875
# 4     TrpR  map00260  4.230704e-04  1.556899e-02   0.230769  0.142857
#
#     f1score   TP  target_set_size  imodulon_size
# 0  0.375000  6.0             19.0           13.0
# 1  0.122449  6.0             85.0           13.0
# 2  0.266667  2.0              2.0           13.0
# 3  0.085106  6.0            128.0           13.0
# 4  0.176471  3.0             21.0           13.0

# %%
DF_module_enrich.head()
# Out:
#   imodulon kegg_id        pvalue        qvalue  precision    recall   f1score  \
# 0     TrpR  M00023  5.002802e-14  9.655408e-12   0.461538  1.000000  0.631579
# 1        4  M00234  3.443926e-07  6.646778e-05   0.230769  1.000000  0.375000
# 2        4  M00238  5.344347e-05  5.157295e-03   0.153846  1.000000  0.266667
# 3        6  M00453  5.344347e-05  1.031459e-02   0.153846  1.000000  0.266667
# 4   FeHm-1  M00009  2.401244e-09  2.317201e-07   0.100000  0.727273  0.175824
#
#     TP  target_set_size  imodulon_size
# 0  6.0              6.0           13.0
# 1  3.0              3.0           13.0
# 2  2.0              2.0           13.0
# 3  2.0              2.0           13.0
# 4  8.0             11.0           80.0

# %% [markdown]
# ### Convert KEGG IDs to human-readable names

# %%
for idx,key in tqdm(DF_pathway_enrich.kegg_id.items(),total=len(DF_pathway_enrich)):
    text = REST.kegg_find('pathway',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_pathway_enrich.loc[idx,'pathway_name'] = name
    except AttributeError:
        DF_pathway_enrich.loc[idx,'pathway_name'] = None
    
for idx,key in tqdm(DF_module_enrich.kegg_id.items(),total=len(DF_module_enrich)):
    text = REST.kegg_find('module',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_module_enrich.loc[idx,'module_name'] = name
    except AttributeError:
        DF_module_enrich.loc[idx,'module_name'] = None
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_299856/516396908.py in <module>
#       1 for idx,key in tqdm(DF_pathway_enrich.kegg_id.items(),total=len(DF_pathway_enrich)):
# ----> 2     text = REST.kegg_find('pathway',key).read()
#       3     try:
#       4         name = re.search('\t(.*)\n',text).group(1)
#       5         DF_pathway_enrich.loc[idx,'pathway_name'] = name
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/Bio/KEGG/REST.py in kegg_find(database, query, option)
#     169         if isinstance(query, list):
#     170             query = "+".join(query)
# --> 171         resp = _q("find", database, query)
#     172
#     173     return resp
#
# ~/anaconda3/envs/modulome/lib/python3.7/site-packages/Bio/KEGG/REST.py in _q(op, arg1, arg2, arg3)
#      42     else:
#      43         args = "%s/%s" % (op, arg1)
# ---> 44     resp = urlopen(URL % (args))
#      45
#      46     if "image" == arg2:
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/envs/modulome/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
DF_pathway_enrich.head()
# Out:
#   imodulon   kegg_id        pvalue        qvalue  precision    recall  \
# 0     TrpR  map00400  1.296331e-09  2.385249e-07   0.461538  0.315789
# 1     TrpR  map01230  1.647545e-05  1.515741e-03   0.461538  0.070588
# 2     TrpR  map00405  5.344347e-05  3.277866e-03   0.153846  1.000000
# 3     TrpR  map01130  1.743338e-04  8.019353e-03   0.461538  0.046875
# 4     TrpR  map00260  4.230704e-04  1.556899e-02   0.230769  0.142857
#
#     f1score   TP  target_set_size  imodulon_size  \
# 0  0.375000  6.0             19.0           13.0
# 1  0.122449  6.0             85.0           13.0
# 2  0.266667  2.0              2.0           13.0
# 3  0.085106  6.0            128.0           13.0
# 4  0.176471  3.0             21.0           13.0
#
#                                         pathway_name
# 0  Phenylalanine, tyrosine and tryptophan biosynt...
# 1                        Biosynthesis of amino acids
# 2                             Phenazine biosynthesis
# 3                                               None
# 4           Glycine, serine and threonine metabolism

# %%
DF_module_enrich.head()
# Out:
#   imodulon kegg_id        pvalue        qvalue  precision    recall   f1score  \
# 0     TrpR  M00023  5.002802e-14  9.655408e-12   0.461538  1.000000  0.631579
# 1        4  M00234  3.443926e-07  6.646778e-05   0.230769  1.000000  0.375000
# 2        4  M00238  5.344347e-05  5.157295e-03   0.153846  1.000000  0.266667
# 3        6  M00453  5.344347e-05  1.031459e-02   0.153846  1.000000  0.266667
# 4   FeHm-1  M00009  2.401244e-09  2.317201e-07   0.100000  0.727273  0.175824
#
#     TP  target_set_size  imodulon_size
# 0  6.0              6.0           13.0
# 1  3.0              3.0           13.0
# 2  2.0              2.0           13.0
# 3  2.0              2.0           13.0
# 4  8.0             11.0           80.0

# %% [markdown]
# ## SubtiWiki categories

# %%
DF_subtiwiki = pd.read_csv(path.join(external_data,'subtiwiki_categories.csv'))
DF_subtiwiki.head()
# Out:
#   SubtiWiki BSU_number  FuncId           FuncName1  \
# 0       dat  BSU_09670  SW 1.1  Cellular processes
# 1       ddl  BSU_04560  SW 1.1  Cellular processes
# 2      glmM  BSU_01770  SW 1.1  Cellular processes
# 3      glmS  BSU_01780  SW 1.1  Cellular processes
# 4      mraY  BSU_15190  SW 1.1  Cellular processes
#
#                          FuncName2            FuncName3  \
# 0  cell envelope and cell division  cell wall synthesis
# 1  cell envelope and cell division  cell wall synthesis
# 2  cell envelope and cell division  cell wall synthesis
# 3  cell envelope and cell division  cell wall synthesis
# 4  cell envelope and cell division  cell wall synthesis
#
#                        FuncName4 FuncName5
# 0  biosynthesis of peptidoglycan       NaN
# 1  biosynthesis of peptidoglycan       NaN
# 2  biosynthesis of peptidoglycan       NaN
# 3  biosynthesis of peptidoglycan       NaN
# 4  biosynthesis of peptidoglycan       NaN

# %%
# Change the subtiwiki annotation format into a list of genes and categories
DF_subtiwiki = DF_subtiwiki.rename({'BSU_number':'gene_id'},axis=1)
DF_subtiwiki = DF_subtiwiki.melt(id_vars='gene_id',value_vars=['FuncName1','FuncName2','FuncName3','FuncName4','FuncName5'])
DF_subtiwiki = DF_subtiwiki[DF_subtiwiki.value.notnull() & DF_subtiwiki.gene_id.isin(ica_data.gene_names)]
DF_subtiwiki.head()
# Out:
#      gene_id   variable               value
# 0  BSU_09670  FuncName1  Cellular processes
# 1  BSU_04560  FuncName1  Cellular processes
# 2  BSU_01770  FuncName1  Cellular processes
# 3  BSU_01780  FuncName1  Cellular processes
# 4  BSU_15190  FuncName1  Cellular processes

# %%
DF_subti_enrich = ica_data.compute_annotation_enrichment(DF_subtiwiki,'value')

# %% [markdown]
# ## Save files

# %%
DF_GO_enrich['source'] = 'GO'
DF_pathway_enrich['source'] = 'KEGG pathways'
DF_module_enrich['source'] = 'KEGG modules'
# DF_subti_enrich['source'] = 'SubtiWiki'

DF_GO_enrich.rename({'gene_ontology':'annotation'},axis=1, inplace=True)
DF_pathway_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)
DF_module_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)
# DF_subti_enrich.rename({'value':'annotation'},axis=1, inplace=True)

DF_enrichments = pd.concat([DF_GO_enrich, DF_pathway_enrich, DF_module_enrich,DF_subti_enrich])
DF_enrichments.to_csv(path.join(data_dir,'functional_enrichments.csv'))

# %% [markdown]
# # Check for single gene iModulons

# %% [markdown]
# Some iModulons are dominated by a single, high-coefficient gene. These iModulons may result from:
# 1. Overdecomposition of the dataset to identify noisy genes
# 1. Artificial knock-out of single genes
# 1. Regulons with only one target gene
#
# No matter what causes these iModulons, it is important to be aware of them. The find_single_gene_imodulons function identifies iModulons that are likely dominated by a single gene.
#
# The iModulons identified by ``find_single_gene_imodulons`` may contain more than one gene, since a threshold-agnostic method is used to identify these iModulons.

# %%
sg_imods = ica_data.find_single_gene_imodulons(save=True)
len(sg_imods)
# Out:
# 9

# %%
for i,mod in enumerate(sg_imods):
    ica_data.rename_imodulons({mod:'SG_'+str(i+1)})

# %%
ica_data.imodulon_table[ica_data.imodulon_table.single_gene == True]
# Out:
#      regulator        pvalue        qvalue  precision  recall   f1score    TP  \
# SG_1       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_2       CRP  1.599720e-17  1.599720e-17   0.769231    0.40  0.526316  10.0
# SG_3       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_4       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_5       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_6       CRP  1.210653e-07  3.026632e-07   0.225806    0.28  0.250000   7.0
# SG_7       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_8       NaN           NaN           NaN        NaN     NaN       NaN   NaN
# SG_9       NaN           NaN           NaN        NaN     NaN       NaN   NaN
#
#       regulon_size  imodulon_size  n_regs single_gene
# SG_1           NaN            NaN     NaN        True
# SG_2          25.0           13.0     1.0        True
# SG_3           NaN            NaN     NaN        True
# SG_4           NaN            NaN     NaN        True
# SG_5           NaN            NaN     NaN        True
# SG_6          25.0           31.0     1.0        True
# SG_7           NaN            NaN     NaN        True
# SG_8           NaN            NaN     NaN        True
# SG_9           NaN            NaN     NaN        True

# %%
ica_data.view_imodulon('SG_1')
# Out:
#            gene_weight gene_name   accession old_locus_tag    start      end  \
# BSU_24620     0.519729      tasA  AL009126.3      BSU24620  2553081  2553866
#
#           strand                    gene_product               COG uniprot  \
# BSU_24620      -  major biofilm matrix component  Function unknown  P54507
#
#            operon                 regulator
# BSU_24620  Op1955  SigA,SinR,RemA,AbrB,LutR

# %% [markdown]
# # Save iModulon object

# %%
from pymodulon.util import explained_variance
from pymodulon.io import *

# %%
# Add iModulon sizes and explained variance
for im in ica_data.imodulon_names:
    ica_data.imodulon_table.loc[im,'imodulon_size'] = len(ica_data.view_imodulon(im))
    ica_data.imodulon_table.loc[im,'explained_variance'] = explained_variance(ica_data,imodulons=im)

# %% [markdown]
# This will save your iModulon table, your thresholds, and any other information stored in the ica_data object.

# %%
save_to_json(ica_data, path.join(d,'interim','kw20.json.gz'))

# %% [markdown]
# If you prefer to view and edit your iModulon table in excel, save it as a CSV and reload the iModulon as before

# %%
ica_data.imodulon_table.to_csv(path.join(d,'interim','imodulon_table_raw.csv'))
